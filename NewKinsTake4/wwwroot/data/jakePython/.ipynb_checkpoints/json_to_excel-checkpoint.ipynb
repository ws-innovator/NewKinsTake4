# %%
import pandas as pd
import logging
import time
import requests
import groq
from groq import Groq
import re

# Configure logging
logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(message)s")

# File paths and table configuration
input_excel_file = r"C:\Users\leeja\Downloads\workflow.xlsx"
sheet_name = "workflow"
column_to_translate = "WorkStageName"
translated_column = "WorkStageNameKo"

# API client setup
client = Groq(api_key="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", max_retries=3)
model_type = "llama3-groq-70b-8192-tool-use-preview"

# System prompt for the translation model
system_prompt = (
    "You are a translation assistant specializing in the finance sector, "
    "familiar with banking system screen functions and workflows. The text you are translating "
    "contains financial jargon and UI labels commonly used in banking software interfaces. "
    "Provide accurate translations in Korean while preserving the context and meaning of the original text."
    "Keep in mind that <br> is there for the purpose of 'Mark down', therefore leave it at its current location."
)

# Function to check if text contains Korean characters
def contains_korean(text):
    return bool(re.search(r'[\uac00-\ud7a3]', str(text)))  # Check for Korean Unicode range

# Translation function using Groq API
def translate_to_korean(text):
    text = text.replace("*", "")
    
    if not text or pd.isna(text) or len(text.strip()) < 5:
        return text

    retries = 3
    for attempt in range(retries):
        try:
            time.sleep(3)
            response = client.chat.completions.create(
                messages=[
                    {"role": "system", "content": system_prompt},
                    {"role": "user", "content": f"Translate the following text to Korean: '{text}'"}
                ],
                model=model_type,
                temperature=0.2,
                max_tokens=500,
                top_p=1,
                stream=False,
                stop="[end_of_sent]",
                seed=100,
            )
            translated_text = response.choices[0].message.content.strip()
            logging.info(f"Translated: {translated_text}")
            return translated_text
        except groq.RateLimitError:
            logging.warning(f"Rate limit error on attempt {attempt + 1}. Retrying...")
            time.sleep(5)
        except groq.APIConnectionError as e:
            logging.error(f"API connection error: {e}")
            break
        except groq.APIStatusError as e:
            logging.error(f"API status error: {e.response}")
            break

    logging.error("Translation failed after multiple retries.")
    return text

# Main function to process the Excel file
def translate_excel_columns():
    try:
        logging.info("Loading data from the Excel file...")
        df = pd.read_excel(input_excel_file, sheet_name=sheet_name)

        # Add the translated column if it doesn't exist
        if translated_column not in df.columns:
            logging.info(f"Adding column: {translated_column}")
            df[translated_column] = None

        # Apply translation only if 'LoadingPageType' is 'Image', and no Korean text is present
        logging.info(f"Translating column: {column_to_translate}")
        df[translated_column] = df.apply(
            lambda row: translate_to_korean(row[column_to_translate]) 
            if row['LoadingPageType'] == 'Image' and 
               pd.notna(row[column_to_translate]) and 
               len(str(row[column_to_translate]).strip()) >= 5 and 
               not contains_korean(row[translated_column])
            else row[translated_column],
            axis=1
        )

        # Save the translated data back to the Excel file
        logging.info("Saving the translated data to the Excel file...")
        backup_file = input_excel_file.replace(".xlsx", "_backup.xlsx")
        df.to_excel(backup_file, sheet_name=sheet_name, index=False)
        df.to_excel(input_excel_file, sheet_name=sheet_name, index=False)
        logging.info("Translation process completed successfully.")

    except FileNotFoundError:
        logging.error(f"File not found: {input_excel_file}")
    except Exception as e:
        logging.error(f"An unexpected error occurred: {e}")

# Execute the script
if __name__ == "__main__":
    translate_excel_columns()
# Out:
# 2024-11-20 23:55:36,279 - Loading data from the Excel file...
# 2024-11-20 23:55:36,595 - Translating column: WorkStageName
# 2024-11-20 23:55:39,917 - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-20 23:55:39,921 - Translated: '????????????????????????????'
# 2024-11-20 23:55:43,185 - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-20 23:55:43,185 - Translated: '입력 텍스트 여기'
# 2024-11-20 23:55:46,458 - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-20 23:55:46,458 - Translated: '????????????????????????????'
# 2024-11-20 23:55:50,242 - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-20 23:55:50,242 - Translated: 이 화면의 기능은 채무면제를 처리하는 것으로, 미납된 금액을 줄이고, 불량貸款에 대한 손실로 기록하는 것입니다. <br><br>① 지정된 필드에 참조 번호를 입력하고 Enter를 누르세요.  <br>② 결과 목록이 검색됩니다.  <br>③ 목록에서 면제 대상자를 선택하세요.  <br>④ Enter를 눌러 면제 프로세스를 완료하세요.  <br><br>이 간소화된 워크플로는 면제 처리와 대출 손실에 대한 적절한 회계 처리를 보장합니다.
# 2024-11-20 23:55:54,031 - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-20 23:55:54,031 - Translated: 이 화면의 기능은 부동산으로 보증된 대출에 대한 예치금 계정을 관리하는 것입니다. 이 화면에서는 보험 및 부동산 유지 비용과 같은 예치금 관련 비용을 주기적으로 기록하고 업데이트할 수 있습니다.<br><br>  ① 참조 번호를 입력하고 Enter 버튼을 클릭합니다.<br>  ② 예치금 세부 정보(금액, 계좌 번호, 효력 날짜)를 입력하고 다시 Enter 버튼을 클릭합니다.<br>  <br>  이러한 프로세스는 예치금 금액이 변경될 때마다 정확한 등록과 업데이트를 보장합니다.
# 2024-11-20 23:55:57,319 - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-20 23:55:57,323 - Translated: '입력 텍스트 여기'
# 2024-11-20 23:56:00,583 - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-20 23:56:00,583 - Translated: '입력 텍스트 여기'
# 2024-11-20 23:56:03,975 - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-20 23:56:03,975 - Translated: 이 화면의 기능은 대출 계정 하위 대장에서 발생한 이자 계정의 잔액 증명서와 이자 요약 증명서를 생성하는 것입니다.
# 2024-11-20 23:56:07,860 - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-20 23:56:07,866 - Translated: 이 화면의 기능은 이자 또는 수수료의 누적액을 조정하여 이자 금액의 차이를 보정하고 대응하는 수표를 생성하는 것입니다. 참고로 이 거래는 [15111] 취소 거래 화면에서 취소할 수 없습니다.<br><br>  ① 참조 번호를 입력하고 Enter 버튼을 클릭하여 거래 세부 정보를 확인합니다.<br>  ② 누적 이자에 대한 보정을 위해 시작 날짜, 종료 날짜, 원금 잔액 및 이자율을 제공합니다.<br>  ③ 세부 정보 버튼을 클릭하여 추가 정보를 입력하고, Enter를 클릭하여 조정을 최종화합니다.<br>  <br>이는 누적 이자 기록의 정확한 업데이트를 보장합니다.
# 2024-11-20 23:56:11,755 - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-20 23:56:11,755 - Translated: 이 화면의 기능은 대출 계정의 연체 상태를 업데이트하는 것입니다. <br>대출 상태를 변경할 때, 발생한 이자는 예약됩니다. 대출은 90일 이상 지연되면 자동으로 NPL (비수익 대출)로 분류됩니다. 그러나 프론트 오피스에서 요청이 있을 경우 수동으로 업데이트할 수도 있습니다.<br><br>이 작업을 수행하려면:<br>① 참조 번호를 입력하고 Enter를 클릭합니다.  <br>② 필요한 경우 대출 상태를 업데이트하고 다시 Enter를 클릭합니다.  <br><br>이 프로세스는 연체 계정 추적을 정확하게 유지하고 지연된 이자 및 대출 상태 업데이트에 대한 요구 사항을 준수합니다.
# 2024-11-20 23:56:15,544 - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-20 23:56:15,559 - Translated: 이 화면의 기능은 대출 계정의 이자 발생 상태를 변경하는 것입니다.  <br>  상태가 이자 발생일 때는 이자 발생 이자가 계정에 반영됩니다.  <br>  상태가 이자 발생이 아닐 때는 이자 발생 이자가 반영되지 않지만 "미수집 이자 II" 카테고리에서 별도로 관리됩니다.  <br>  <br>  ① 검색 조건을 입력하고 Search 버튼을 클릭합니다.<br>  ② 이자 발생 상태를 이자 발생이 아니도록 변경합니다.<br>  ③ Enter 버튼을 눌러 변경 사항을 저장합니다.
# 2024-11-20 23:56:19,331 - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-20 23:56:19,331 - Translated: 이 화면의 기능은 현재 NPL (Non-Performing Loan)로 등록된 계정의 이자 지급 상태를 정상으로 업데이트하는 것입니다. 이는 채무자의 신용 회복과 같은 개선 사항을 반영합니다.<br><br>① 원하는 검색 기준을 입력하고 검색 버튼을 클릭합니다. <br>  ② 계정 정보가 표시되면 이자 지급 상태 필드를 정상으로 변경합니다. <br>  ③ 업데이트를 최종화하는 Enter 버튼을 클릭합니다.  <br><br>이러한 프로세스는 채무자의 상태 변화로 더 이상 NPL로 자격이 없는 계정의 정확한 추적을 보장합니다.
# 2024-11-20 23:56:22,609 - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-20 23:56:22,612 - Translated: '입력 텍스트 여기'
# 2024-11-20 23:56:25,888 - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-20 23:56:25,888 - Translated: '입력 텍스트 여기'
# 2024-11-20 23:56:29,152 - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-20 23:56:29,168 - Translated: '입력 텍스트 여기'
# 2024-11-20 23:56:32,441 - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-20 23:56:32,441 - Translated: '입력 텍스트 여기'
# 2024-11-20 23:56:35,713 - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-20 23:56:35,713 - Translated: '입력 텍스트 여기'
# 2024-11-20 23:56:38,999 - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-20 23:56:38,999 - Translated: '입력 텍스트 여기'
# 2024-11-20 23:56:42,256 - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-20 23:56:42,272 - Translated: '입력 텍스트 여기'
